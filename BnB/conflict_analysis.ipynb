# %%
import highspy

# %%
class Cut():
    def __init__(self, var_id, lower, upper):
        self.var_id = var_id
        self.lower = lower
        self.upper = upper

    def __str__(self):
        return f"Cut[id: {self.var_id}, lower: {self.lower}, upper: {self.upper}]"

# %%
class StackItem():
    def __init__(self, cuts, solution, dual_value):
        self.cuts = cuts
        self.solution = solution.col_value
        self.dual_value = dual_value

    def __str__(self):
        text = "StackItem{\n\tCuts:\n"
        for cut in self.cuts:
            text += "\t\t" + str(cut) + "\n"
        text += "\tSolution:\n\t\t" + str(self.solution) + "\n"
        text += "\tDual value:\n\t\t" + str(self.dual_value) + "\n}"
        return text

# %%
class BnB:
    def __init__(self, solver, generalize, eps):
        self.__solver = solver
        self.__generalize = generalize
        self.__eps = eps

        self.__solver.run()
        self.__dual_value = self.__solver.getInfo().objective_function_value
        self.__stack = [StackItem([], self.__solver.getSolution(), self.__dual_value)]

    def start(self):
        stack_item = self.__stack.pop()
        
        while stack_item is not None:

            print(stack_item)
            
            if self.check_on_primal(stack_item.solution):
                print(stack_item.solution)
                
            left_cut, right_cut = self.find_cut(stack_item)
            print(left_cut, "|", right_cut)
            
            while left_cut is None and right_cut is None:
                if not self.__stack:
                    return
                stack_item = self.__stack.pop()
                left_cut, right_cut = self.find_cut(stack_item)
                self.__dual_value = stack_item.dual_value

            left_solver = highspy.Highs()
            left_solver.passModel(self.__solver.getModel())
            left_solver.silent()
            left_solver.changeColBounds(left_cut.var_id, left_cut.lower, left_cut.upper)
            
            right_solver = highspy.Highs()
            right_solver.passModel(self.__solver.getModel())
            right_solver.silent()
            right_solver.changeColBounds(right_cut.var_id, right_cut.lower, right_cut.upper)
            for cut in stack_item.cuts:
                left_solver.changeColBounds(cut.var_id, cut.lower, cut.upper)
                right_solver.changeColBounds(cut.var_id, cut.lower, cut.upper)

            left_solver.run()
            right_solver.run()

            left_objective_function_value = left_solver.getInfo().objective_function_value
            right_objective_function_value = right_solver.getInfo().objective_function_value

            if left_objective_function_value < right_objective_function_value:
                self.__dual_value = left_objective_function_value
                self.__stack += [StackItem(stack_item.cuts + [right_cut], right_solver.getSolution(), right_objective_function_value)]
                stack_item = StackItem(stack_item.cuts + [left_cut], left_solver.getSolution(), left_objective_function_value)
            else:
                self.__dual_value = right_objective_function_value
                self.__stack += [StackItem(stack_item.cuts + [left_cut], left_solver.getSolution(), left_objective_function_value)]
                stack_item = StackItem(stack_item.cuts + [right_cut], right_solver.getSolution(), right_objective_function_value)

    def check_on_primal(self, dual_value):
        for icol in self.__generalize:
            if abs(dual_value[icol] - (dual_value[icol] // 1)) > self.__eps:
                return False
        return True

    def find_cut(self, stack_item):
        heuristics = lambda value: abs(value - 0.5)
        res_id = 0
        res_func_value = self.__solver.inf
        lower = 0
        lower_res = 0
        find_one = False
        
        for icol in self.__generalize:
            value = stack_item.solution[icol]
            lower = value // 1
            
            if abs(lower - value) > self.__eps:
                val = heuristics(value - lower)
                if val < res_func_value:
                    res_id = icol
                    res_func_value = val
                    find_one = True
                    lower_res = int(lower)
        if find_one:
            return (Cut(res_id, 0, lower_res), Cut(res_id, lower_res + 1, self.__solver.inf))
        return (None, None)

# %%
help(h.getModelStatus())
# Out:
# Help on HighsModelStatus in module highspy._core object:
#
# class HighsModelStatus(pybind11_builtins.pybind11_object)
#  |  Method resolution order:
#  |      HighsModelStatus
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(...)
#  |      __eq__(self: object, other: object) -> bool
#  |
#  |  __getstate__(...)
#  |      __getstate__(self: object) -> int
#  |
#  |  __hash__(...)
#  |      __hash__(self: object) -> int
#  |
#  |  __index__(...)
#  |      __index__(self: highspy._core.HighsModelStatus) -> int
#  |
#  |  __init__(...)
#  |      __init__(self: highspy._core.HighsModelStatus, value: int) -> None
#  |
#  |  __int__(...)
#  |      __int__(self: highspy._core.HighsModelStatus) -> int
#  |
#  |  __ne__(...)
#  |      __ne__(self: object, other: object) -> bool
#  |
#  |  __repr__(...)
#  |      __repr__(self: object) -> str
#  |
#  |  __setstate__(...)
#  |      __setstate__(self: highspy._core.HighsModelStatus, state: int) -> None
#  |
#  |  __str__(...)
#  |      __str__(self: object) -> str
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  __members__
#  |
#  |  name
#  |      name(self: object) -> str
#  |
#  |  value
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  kInfeasible = <HighsModelStatus.kInfeasible: 8>
#  |
#  |  kInterrupt = <HighsModelStatus.kInterrupt: 17>
#  |
#  |  kIterationLimit = <HighsModelStatus.kIterationLimit: 14>
#  |
#  |  kLoadError = <HighsModelStatus.kLoadError: 1>
#  |
#  |  kMemoryLimit = <HighsModelStatus.kMemoryLimit: 18>
#  |
#  |  kModelEmpty = <HighsModelStatus.kModelEmpty: 6>
#  |
#  |  kModelError = <HighsModelStatus.kModelError: 2>
#  |
#  |  kNotset = <HighsModelStatus.kNotset: 0>
#  |
#  |  kObjectiveBound = <HighsModelStatus.kObjectiveBound: 11>
#  |
#  |  kObjectiveTarget = <HighsModelStatus.kObjectiveTarget: 12>
#  |
#  |  kOptimal = <HighsModelStatus.kOptimal: 7>
#  |
#  |  kPostsolveError = <HighsModelStatus.kPostsolveError: 5>
#  |
#  |  kPresolveError = <HighsModelStatus.kPresolveError: 3>
#  |
#  |  kSolutionLimit = <HighsModelStatus.kSolutionLimit: 16>
#  |
#  |  kSolveError = <HighsModelStatus.kSolveError: 4>
#  |
#  |  kTimeLimit = <HighsModelStatus.kTimeLimit: 13>
#  |
#  |  kUnbounded = <HighsModelStatus.kUnbounded: 10>
#  |
#  |  kUnboundedOrInfeasible = <HighsModelStatus.kUnboundedOrInfeasible: 9>
#  |
#  |  kUnknown = <HighsModelStatus.kUnknown: 15>
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
help(h)
# Out:
# Help on Highs in module highspy.highs object:
#
# class Highs(highspy._core._Highs)
#  |  HiGHS solver interface
#  |
#  |  Method resolution order:
#  |      Highs
#  |      highspy._core._Highs
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      __init__(self: highspy._core._Highs) -> None
#  |
#  |  addBinaries(
#  |      self,
#  |      *nvars: 'Union[int, Mapping[Any, Any], Sequence[Any]]',
#  |      **kwargs: 'Union[Any, HighsVarType, Mapping[Any, Any], Sequence[Any]]'
#  |  )
#  |      Alias for the addVariables method, for binary variables.
#  |
#  |  addBinary(self, obj: 'float' = 0.0, name: 'Optional[str]' = None)
#  |      Alias for the addVariable method, for binary variables.
#  |
#  |  addConstr(self, expr: 'highs_linear_expression', name: 'Optional[str]' = None)
#  |      Adds a constraint to the model.
#  |
#  |      Args:
#  |          expr: A highs_linear_expression to be added.
#  |          name: Optional name of the constraint.
#  |
#  |      Returns:
#  |          A highs_con object representing the added constraint.
#  |
#  |  addConstrs(
#  |      self,
#  |      *args: 'Union[highs_linear_expression, Iterable[highs_linear_expression]]',
#  |      **kwargs: 'Optional[Union[str, Sequence[str]]]'
#  |  )
#  |      Adds multiple constraints to the model.
#  |
#  |      Args:
#  |          *args: A sequence of highs_linear_expression to be added.
#  |
#  |          **kwargs: Optional keyword arguments.
#  |              name_prefix: Prefix for the constraint names.  Constructed name will be name_prefix + index.
#  |              name: A collection of names for the constraints (list or mapping).
#  |
#  |      Returns:
#  |          A highs_con collection array representing the added constraints.
#  |
#  |  addIntegral(
#  |      self,
#  |      lb: 'float' = 0.0,
#  |      ub: 'float' = inf,
#  |      obj: 'float' = 0.0,
#  |      name: 'Optional[str]' = None
#  |  )
#  |      Alias for the addVariable method, for integer variables.
#  |
#  |  addIntegrals(
#  |      self,
#  |      *nvars: 'Union[int, Mapping[Any, Any], Sequence[Any]]',
#  |      **kwargs: 'Union[Any, HighsVarType, Mapping[Any, Any], Sequence[Any]]'
#  |  )
#  |      Alias for the addVariables method, for integer variables.
#  |
#  |  addVariable(
#  |      self,
#  |      lb: 'float' = 0,
#  |      ub: 'float' = inf,
#  |      obj: 'float' = 0.0,
#  |      type: 'HighsVarType' = <HighsVarType.kContinuous: 0>,
#  |      name: 'Optional[str]' = None
#  |  )
#  |      Adds a variable to the model.
#  |
#  |      Args:
#  |          lb: Lower bound of the variable (default is 0).
#  |          ub: Upper bound of the variable (default is infinity).
#  |          obj: Objective coefficient of the variable (default is 0).
#  |          type: Type of the variable (continuous, integer; default is continuous).
#  |          name: Optional name for the variable.
#  |
#  |      Returns:
#  |          A highs_var object representing the added variable.
#  |
#  |  addVariables(
#  |      self,
#  |      *nvars: 'Union[int, Mapping[Any, Any], Sequence[Any]]',
#  |      **kwargs: 'Union[Any, HighsVarType, Mapping[Any, Any], Sequence[Any]]'
#  |  ) -> 'Optional[Union[dict[Any, highs_var], HighspyArray]]'
#  |      Adds multiple variables to the model.
#  |
#  |      Args:
#  |          *args: A sequence of variables to be added. Can be a collection of scalars or indices (or mix).
#  |
#  |          **kwargs: Optional keyword arguments.  Can be scalars, arrays, or mappings.
#  |              lb: Lower bound of the variables (default is 0).
#  |              ub: Upper bound of the variables (default is infinity).
#  |              obj: Objective coefficient of the variables (default is 0).
#  |              type: Type of the variables (continuous, integer; default is continuous).
#  |              name: A collection of names for the variables (list or mapping).
#  |              name_prefix: Prefix for the variable names.  Constructed name will be name_prefix + index.
#  |              out_array: Return an array of highs_var objects instead of a dictionary.
#  |
#  |      Returns:
#  |          A highs_var collection (array or dictionary) representing the added variables.
#  |
#  |  allConstrDuals(self)
#  |      Retrieves the dual values of all constraints in the solution.
#  |
#  |      Returns:
#  |          A list of dual values for all constraints in the solution.
#  |
#  |  allConstrValues(self)
#  |      Retrieves the values of all constraints in the solution.
#  |
#  |      Returns:
#  |          A list of values for all constraints in the solution.
#  |
#  |  allVariableDuals(self)
#  |      Retrieves the dual values of all variables in the solution.
#  |
#  |      Returns:
#  |          A list of dual values for all variables in the solution.
#  |
#  |  allVariableNames(self) -> 'list[str]'
#  |      Retrieves the names of all variables in the model.
#  |
#  |      Returns:
#  |          A list of strings representing the names of all variables.
#  |
#  |  allVariableValues(self)
#  |      Retrieves the values of all variables in the solution.
#  |
#  |      Returns:
#  |          A list of values for all variables in the solution.
#  |
#  |  cancelSolve(self)
#  |      If HandleUserInterrupt is enabled, this method will signal the solver to stop.
#  |
#  |  chgCoeff(
#  |      self,
#  |      cons: 'Union[highs_cons, Integral]',
#  |      var: 'Union[highs_var, Integral]',
#  |      val: 'float'
#  |  )
#  |      Changes the coefficient of a variable in a constraint.
#  |
#  |      Args:
#  |          cons: A highs_con object representing the constraint.
#  |          var: A highs_var object representing the variable.
#  |          val: The new coefficient value for the variable in the constraint.
#  |
#  |  constrDual(
#  |      self,
#  |      con: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the dual value of a specific constraint in the solution.
#  |
#  |      Args:
#  |          con: A highs_con object representing the constraint.
#  |
#  |      Returns:
#  |          The dual value of the specified constraint in the solution.
#  |
#  |  constrDuals(
#  |      self,
#  |      cons: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the dual values of multiple constraints in the solution.
#  |
#  |      Args:
#  |          cons: A collection of highs_con objects representing the constraints. Can be a Mapping (e.g., dict) where keys are constraint names and values are highs_con objects, or an iterable of highs_con objects.
#  |
#  |      Returns:
#  |          If cons is a Mapping, returns a dict where keys are the same keys from the input cons and values are the dual values of the corresponding constraints. If cons is an iterable, returns a list of dual values for the constraints.
#  |
#  |  constrValue(
#  |      self,
#  |      con: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the value of a specific constraint in the solution.
#  |
#  |      Args:
#  |          con: A highs_con object representing the constraint.
#  |
#  |      Returns:
#  |          The value of the specified constraint in the solution.
#  |
#  |  constrValues(
#  |      self,
#  |      cons: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the values of multiple constraints in the solution.
#  |
#  |      Args:
#  |          cons: A collection of highs_con objects representing the constraints. Can be a Mapping (e.g., dict) where keys are constraint names and values are highs_con objects, or an iterable of highs_con objects.
#  |
#  |      Returns:
#  |          If cons is a Mapping, returns a dict where keys are the same keys from the input cons and values are the solution values of the corresponding constraints. If cons is an iterable, returns a list of solution values for the constraints.
#  |
#  |  deleteVariable(
#  |      self,
#  |      var_or_index: 'Union[Integral, highs_var]',
#  |      *args: 'Union[Mapping[Any, highs_var], Iterable[highs_var], highs_var]'
#  |  )
#  |      Deletes a variable from the model and updates the indices of subsequent variables in provided collections.
#  |
#  |      Args:
#  |          var_or_index: A highs_var object or an index representing the variable to be deleted.
#  |          *args: Optional collections (lists, dicts, etc.) of highs_var objects whose indices need to be updated.
#  |
#  |  disableCallbacks(self)
#  |      Disables all callbacks.
#  |
#  |  enableCallbacks(self)
#  |      Enables callbacks, restarting them if they were previously enabled.
#  |
#  |  expr(
#  |      self,
#  |      optional: 'Optional[Union[float, int, highs_var, highs_linear_expression]]' = None
#  |  )
#  |      Creates a new highs_linear_expression object.
#  |
#  |      Returns:
#  |          A highs_linear_expression object.
#  |
#  |  getConstrs(self)
#  |      Retrieves all constraints in the model.
#  |
#  |      Returns:
#  |          A list of highs_cons objects, each representing a constraint in the model.
#  |
#  |  getExpr(self, cons: 'Union[Integral, highs_cons]')
#  |      Retrieves the highs_linear_expression of a constraint.
#  |
#  |      Args:
#  |          cons: A highs_con object or index representing the constraint.
#  |
#  |      Returns:
#  |          A highs_linear_expression object representing the expression of the constraint.
#  |
#  |  getVariables(self)
#  |      Retrieves all variables in the model.
#  |
#  |      Returns:
#  |          A list of highs_var objects, each representing a variable in the model.
#  |
#  |  is_solver_running(self)
#  |
#  |  joinSolve(
#  |      self,
#  |      solver_thread: 'Optional[Thread]' = None,
#  |      interrupt_limit: 'int' = 5
#  |  )
#  |      Waits for the solver to finish. If solver_thread is provided, it will handle KeyboardInterrupts.
#  |
#  |      Args:
#  |          solver_thread: A Thread object representing the solver thread (optional).
#  |          interrupt_limit: The number of times to allow KeyboardInterrupt before forcing termination (optional).
#  |
#  |      Returns:
#  |          A HighsStatus object containing the solve status.
#  |
#  |  maximize(
#  |      self,
#  |      obj: 'Optional[Union[highs_var, highs_linear_expression]]' = None
#  |  )
#  |      Solves a maximization of the objective and optionally updates the costs.
#  |
#  |      Args:
#  |          obj: An optional highs_linear_expression representing the new objective function.
#  |
#  |      Raises:
#  |          Exception: If obj is an inequality or not a highs_linear_expression.
#  |
#  |      Returns:
#  |          A HighsStatus object containing the solve status after maximization.
#  |
#  |  minimize(
#  |      self,
#  |      obj: 'Optional[Union[highs_var, highs_linear_expression]]' = None
#  |  )
#  |      Solves a minimization of the objective and optionally updates the costs.
#  |
#  |      Args:
#  |          obj: An optional highs_linear_expression representing the new objective function.
#  |
#  |      Raises:
#  |          Exception: If obj is an inequality or not a highs_linear_expression.
#  |
#  |      Returns:
#  |          A HighsStatus object containing the solve status after minimization.
#  |
#  |  optimize(self)
#  |      Alias for the solve method.
#  |
#  |  removeConstr(
#  |      self,
#  |      cons_or_index: 'Union[highs_cons, Integral]',
#  |      *args: 'Union[Mapping[Any, highs_cons], Sequence[highs_cons], highs_cons]'
#  |  )
#  |      Removes a constraint from the model and updates the indices of subsequent constraints in provided collections.
#  |
#  |      Args:
#  |          cons_or_index: A highs_cons object or an index representing the constraint to be removed.
#  |          *args: Optional collections (lists, dicts, etc.) of highs_cons objects whose indices need to be updated after the removal.
#  |
#  |  setContinuous(
#  |      self,
#  |      var_or_collection: 'Union[highs_var, int, Iterable[Union[highs_var, int]]]'
#  |  )
#  |      Sets a variable/collection to continuous.
#  |
#  |      Args:
#  |          var_or_collection: A highs_var object/collection representing the variable to be set as continuous.
#  |
#  |  setInteger(
#  |      self,
#  |      var_or_collection: 'Union[highs_var, int, Iterable[Union[highs_var, int]]]'
#  |  )
#  |      Sets a variable/collection to integer.
#  |
#  |      Args:
#  |          var_or_collection: A highs_var object/collection representing the variable to be set as integer.
#  |
#  |  setMaximize(self)
#  |      Sets the objective sense of the model to maximization.
#  |
#  |  setMinimize(self)
#  |      Sets the objective sense of the model to minimization.
#  |
#  |  silent(self, turn_off_output: 'bool' = True)
#  |      Disables solver output to the console.
#  |
#  |  solve(self)
#  |      Runs the solver on the current problem.
#  |
#  |      Returns:
#  |          A HighsStatus object containing the solve status.
#  |
#  |  startSolve(self)
#  |      Starts the solver in a separate thread.  Useful for handling KeyboardInterrupts.
#  |      Do not attempt to modify the model while the solver is running.
#  |
#  |      Returns:
#  |          A Thread object representing the solver thread.
#  |
#  |  val(
#  |      self,
#  |      var: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], Sequence[Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Gets the value of a variable/index or expression in the solution.
#  |
#  |      Args:
#  |          var: A highs_var/index or highs_linear_expression object representing the variable.
#  |
#  |      Returns:
#  |          The value of the variable in the solution.
#  |
#  |  vals(
#  |      self,
#  |      idxs: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], Sequence[Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Gets the values of multiple variables in the solution.
#  |
#  |      Args:
#  |          idxs: A collection of highs_var objects representing the variables. Can be a Mapping (e.g., dict) where keys are variable names and values are highs_var objects, or an iterable of highs_var objects.
#  |
#  |      Returns:
#  |          If idxs is a Mapping, returns a dict where keys are the same keys from the input idxs and values are the solution values of the corresponding variables. If idxs is an iterable, returns a list of solution values for the variables.
#  |
#  |  variableDual(
#  |      self,
#  |      var: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the dual value of a specific variable/index or expression in the solution.
#  |
#  |      Args:
#  |          var: A highs_var object representing the variable.
#  |
#  |      Returns:
#  |          The dual value of the specified variable in the solution.
#  |
#  |  variableDuals(
#  |      self,
#  |      idxs: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the dual values of multiple variables in the solution.
#  |
#  |      Args:
#  |          idxs: A collection of highs_var objects representing the variables. Can be a Mapping (e.g., dict) where keys are variable names and values are highs_var objects, or an iterable of highs_var objects.
#  |
#  |      Returns:
#  |          If idxs is a Mapping, returns a dict where keys are the same keys from the input idxs and values are the dual values of the corresponding variables. If idxs is an iterable, returns a list of dual values for the variables.
#  |
#  |  variableName(self, var: 'Union[Integral, highs_var]')
#  |      Retrieves the name of a specific variable.
#  |
#  |      Args:
#  |          var: A highs_var object representing the variable.
#  |
#  |      Raises:
#  |          Exception: If the variable name cannot be found.
#  |
#  |      Returns:
#  |          The name of the specified variable.
#  |
#  |  variableNames(self, idxs: 'Iterable[Union[highs_var, Integral]]')
#  |      Retrieves the names of multiple variables.
#  |
#  |      Args:
#  |          idxs: An iterable of highs_var objects or a mapping where keys are identifiers and values are highs_var objects.
#  |
#  |      Raises:
#  |          Exception: If any variable name cannot be found.
#  |
#  |      Returns:
#  |          If idxs is a mapping, returns a dict where keys are the same keys from the input idxs and values are the names of the corresponding variables.
#  |          If idxs is an iterable, returns a list of names for the specified variables.
#  |
#  |  variableValue(
#  |      self,
#  |      var: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the value of a specific variable in the solution.
#  |
#  |      Args:
#  |          var: A highs_var object representing the variable.
#  |
#  |      Returns:
#  |          The value of the specified variable in the solution.
#  |
#  |  variableValues(
#  |      self,
#  |      idxs: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  )
#  |      Retrieves the values of multiple variables in the solution.
#  |
#  |      Args:
#  |          idxs: A collection of highs_var objects representing the variables. Can be a Mapping (e.g., dict) where keys are variable names and values are highs_var objects, or an iterable of highs_var objects.
#  |
#  |      Returns:
#  |          If idxs is a Mapping, returns a dict where keys are the same keys from the input idxs and values are the solution values of the corresponding variables. If idxs is an iterable, returns a list of solution values for the variables.
#  |
#  |  wait(self, timeout: 'float' = -1.0)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  internal_get_value(
#  |      array_values: 'Union[Sequence[float], np.ndarray[Any, np.dtype[np.float64]], readonly_ptr_wrapper_double]',
#  |      index_collection: 'Union[Integral, highs_var, highs_cons, highs_linear_expression, Mapping[Any, Any], Sequence[Any], np.ndarray[Any, np.dtype[Any]]]'
#  |  ) -> 'Union[float, bool, Mapping[Any, Any], np.ndarray[Any, np.dtype[np.float64]]]'
#  |      Internal method to get the value of an index from an array of values. Could be value or dual, variable or constraint.
#  |
#  |  qsum(
#  |      items: 'Union[Iterable[Union[highs_var, highs_linear_expression]], np.ndarray[Any, np.dtype[np.object_]]]',
#  |      initial: 'Optional[Union[float, int, highs_var, highs_linear_expression]]' = None
#  |  )
#  |      Performs a faster sum for highs_linear_expressions.
#  |
#  |      Args:
#  |          items: A collection of highs_linear_expressions or highs_vars to be summed.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  inf
#  |      Represents infinity in the context of the solver.
#  |
#  |      Returns:
#  |          The value used to represent infinity.
#  |
#  |  numConstrs
#  |      Gets the number of constraints in the model.
#  |
#  |      Returns:
#  |          The number of constraints.
#  |
#  |  numVariables
#  |      Gets the number of variables in the model.
#  |
#  |      Returns:
#  |          The number of variables.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  HandleKeyboardInterrupt
#  |      Get/Set whether the solver should handle KeyboardInterrupt (i.e., cancel solve on Ctrl+C). Also enables/disables HandleUserInterrupt.
#  |
#  |  HandleUserInterrupt
#  |      Get/Set whether the solver should handle user interrupts (i.e., cancel solve on user request)
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  cbIpmInterrupt
#  |
#  |  cbLogging
#  |
#  |  cbMipDefineLazyConstraints
#  |
#  |  cbMipGetCutPool
#  |
#  |  cbMipImprovingSolution
#  |
#  |  cbMipInterrupt
#  |
#  |  cbMipLogging
#  |
#  |  cbMipSolution
#  |
#  |  cbSimplexInterrupt
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'_Highs__handle_keyboard_interrupt': 'bool', '_High...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from highspy._core._Highs:
#  |
#  |  addCol(...)
#  |      addCol(self: highspy._core._Highs, arg0: float, arg1: float, arg2: float, arg3: int, arg4: numpy.ndarray[numpy.int32], arg5: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  addCols(...)
#  |      addCols(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.float64], arg2: numpy.ndarray[numpy.float64], arg3: numpy.ndarray[numpy.float64], arg4: int, arg5: numpy.ndarray[numpy.int32], arg6: numpy.ndarray[numpy.int32], arg7: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  addLinearObjective(...)
#  |      addLinearObjective(self: highspy._core._Highs, arg0: HighsLinearObjective) -> highspy._core.HighsStatus
#  |
#  |  addRow(...)
#  |      addRow(self: highspy._core._Highs, arg0: float, arg1: float, arg2: int, arg3: numpy.ndarray[numpy.int32], arg4: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  addRows(...)
#  |      addRows(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.float64], arg2: numpy.ndarray[numpy.float64], arg3: int, arg4: numpy.ndarray[numpy.int32], arg5: numpy.ndarray[numpy.int32], arg6: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  addVar(...)
#  |      addVar(self: highspy._core._Highs, arg0: float, arg1: float) -> highspy._core.HighsStatus
#  |
#  |  addVars(...)
#  |      addVars(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.float64], arg2: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  basisStatusToString(...)
#  |      basisStatusToString(self: highspy._core._Highs, arg0: highspy._core.HighsBasisStatus) -> str
#  |
#  |  basisValidityToString(...)
#  |      basisValidityToString(self: highspy._core._Highs, arg0: int) -> str
#  |
#  |  changeCoeff(...)
#  |      changeCoeff(self: highspy._core._Highs, arg0: int, arg1: int, arg2: float) -> highspy._core.HighsStatus
#  |
#  |  changeColBounds(...)
#  |      changeColBounds(self: highspy._core._Highs, arg0: int, arg1: float, arg2: float) -> highspy._core.HighsStatus
#  |
#  |  changeColCost(...)
#  |      changeColCost(self: highspy._core._Highs, arg0: int, arg1: float) -> highspy._core.HighsStatus
#  |
#  |  changeColIntegrality(...)
#  |      changeColIntegrality(self: highspy._core._Highs, arg0: int, arg1: highspy._core.HighsVarType) -> highspy._core.HighsStatus
#  |
#  |  changeColsBounds(...)
#  |      changeColsBounds(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32], arg2: numpy.ndarray[numpy.float64], arg3: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  changeColsCost(...)
#  |      changeColsCost(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32], arg2: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  changeColsIntegrality(...)
#  |      changeColsIntegrality(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32], arg2: numpy.ndarray[numpy.uint8]) -> highspy._core.HighsStatus
#  |
#  |  changeObjectiveOffset(...)
#  |      changeObjectiveOffset(self: highspy._core._Highs, arg0: float) -> highspy._core.HighsStatus
#  |
#  |  changeObjectiveSense(...)
#  |      changeObjectiveSense(self: highspy._core._Highs, arg0: highspy._core.ObjSense) -> highspy._core.HighsStatus
#  |
#  |  changeRowBounds(...)
#  |      changeRowBounds(self: highspy._core._Highs, arg0: int, arg1: float, arg2: float) -> highspy._core.HighsStatus
#  |
#  |  clear(...)
#  |      clear(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  clearLinearObjectives(...)
#  |      clearLinearObjectives(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  clearModel(...)
#  |      clearModel(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  clearSolver(...)
#  |      clearSolver(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  crossover(...)
#  |      crossover(self: highspy._core._Highs, arg0: HighsSolution) -> highspy._core.HighsStatus
#  |
#  |  deleteCols(...)
#  |      deleteCols(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> highspy._core.HighsStatus
#  |
#  |  deleteRows(...)
#  |      deleteRows(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> highspy._core.HighsStatus
#  |
#  |  deleteVars(...)
#  |      deleteVars(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> highspy._core.HighsStatus
#  |
#  |  feasibilityRelaxation(...)
#  |      feasibilityRelaxation(self: highspy._core._Highs, global_lower_penalty: float, global_upper_penalty: float, global_rhs_penalty: float, local_lower_penalty: object = None, local_upper_penalty: object = None, local_rhs_penalty: object = None) -> highspy._core.HighsStatus
#  |
#  |  getBasis(...)
#  |      getBasis(self: highspy._core._Highs) -> HighsBasis
#  |
#  |  getCol(...)
#  |      getCol(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, float, float, float, int]
#  |
#  |  getColByName(...)
#  |      getColByName(self: highspy._core._Highs, arg0: str) -> tuple[highspy._core.HighsStatus, int]
#  |
#  |  getColEntries(...)
#  |      getColEntries(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, numpy.ndarray[numpy.int32], numpy.ndarray[numpy.float64]]
#  |
#  |  getColIntegrality(...)
#  |      getColIntegrality(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, highspy._core.HighsVarType]
#  |
#  |  getColName(...)
#  |      getColName(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, str]
#  |
#  |  getCols(...)
#  |      getCols(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> tuple[highspy._core.HighsStatus, int, numpy.ndarray[numpy.float64], numpy.ndarray[numpy.float64], numpy.ndarray[numpy.float64], int]
#  |
#  |  getColsEntries(...)
#  |      getColsEntries(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> tuple[highspy._core.HighsStatus, numpy.ndarray[numpy.int32], numpy.ndarray[numpy.int32], numpy.ndarray[numpy.float64]]
#  |
#  |  getHessianNumNz(...)
#  |      getHessianNumNz(self: highspy._core._Highs) -> int
#  |
#  |  getIis(...)
#  |      getIis(self: highspy._core._Highs, arg0: HighsIis) -> highspy._core.HighsStatus
#  |
#  |  getInfinity(...)
#  |      getInfinity(self: highspy._core._Highs) -> float
#  |
#  |  getInfo(...)
#  |      getInfo(self: highspy._core._Highs) -> highspy._core.HighsInfo
#  |
#  |  getInfoType(...)
#  |      getInfoType(self: highspy._core._Highs, arg0: str) -> tuple[highspy._core.HighsStatus, highspy._core.HighsInfoType]
#  |
#  |  getInfoValue(...)
#  |      getInfoValue(self: highspy._core._Highs, arg0: str) -> tuple[highspy._core.HighsStatus, object]
#  |
#  |  getLp(...)
#  |      getLp(self: highspy._core._Highs) -> highspy._core.HighsLp
#  |
#  |  getModel(...)
#  |      getModel(self: highspy._core._Highs) -> highspy._core.HighsModel
#  |
#  |  getModelPresolveStatus(...)
#  |      getModelPresolveStatus(self: highspy._core._Highs) -> highspy._core.HighsPresolveStatus
#  |
#  |  getModelStatus(...)
#  |      getModelStatus(self: highspy._core._Highs) -> highspy._core.HighsModelStatus
#  |
#  |  getNumCol(...)
#  |      getNumCol(self: highspy._core._Highs) -> int
#  |
#  |  getNumNz(...)
#  |      getNumNz(self: highspy._core._Highs) -> int
#  |
#  |  getNumRow(...)
#  |      getNumRow(self: highspy._core._Highs) -> int
#  |
#  |  getObjectiveOffset(...)
#  |      getObjectiveOffset(self: highspy._core._Highs) -> tuple[highspy._core.HighsStatus, float]
#  |
#  |  getObjectiveSense(...)
#  |      getObjectiveSense(self: highspy._core._Highs) -> tuple[highspy._core.HighsStatus, highspy._core.ObjSense]
#  |
#  |  getObjectiveValue(...)
#  |      getObjectiveValue(self: highspy._core._Highs) -> float
#  |
#  |  getOptionType(...)
#  |      getOptionType(self: highspy._core._Highs, arg0: str) -> tuple[highspy._core.HighsStatus, highspy._core.HighsOptionType]
#  |
#  |  getOptionValue(...)
#  |      getOptionValue(self: highspy._core._Highs, arg0: str) -> tuple[highspy._core.HighsStatus, object]
#  |
#  |  getOptions(...)
#  |      getOptions(self: highspy._core._Highs) -> highspy._core.HighsOptions
#  |
#  |  getPresolvedLp(...)
#  |      getPresolvedLp(self: highspy._core._Highs) -> highspy._core.HighsLp
#  |
#  |  getRanging(...)
#  |      getRanging(self: highspy._core._Highs) -> tuple[highspy._core.HighsStatus, HighsRanging]
#  |
#  |  getRow(...)
#  |      getRow(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, float, float, int]
#  |
#  |  getRowByName(...)
#  |      getRowByName(self: highspy._core._Highs, arg0: str) -> tuple[highspy._core.HighsStatus, int]
#  |
#  |  getRowEntries(...)
#  |      getRowEntries(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, numpy.ndarray[numpy.int32], numpy.ndarray[numpy.float64]]
#  |
#  |  getRowName(...)
#  |      getRowName(self: highspy._core._Highs, arg0: int) -> tuple[highspy._core.HighsStatus, str]
#  |
#  |  getRows(...)
#  |      getRows(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> tuple[highspy._core.HighsStatus, int, numpy.ndarray[numpy.float64], numpy.ndarray[numpy.float64], int]
#  |
#  |  getRowsEntries(...)
#  |      getRowsEntries(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32]) -> tuple[highspy._core.HighsStatus, numpy.ndarray[numpy.int32], numpy.ndarray[numpy.int32], numpy.ndarray[numpy.float64]]
#  |
#  |  getRunTime(...)
#  |      getRunTime(self: highspy._core._Highs) -> float
#  |
#  |  getSavedMipSolutions(...)
#  |      getSavedMipSolutions(self: highspy._core._Highs) -> list[HighsObjectiveSolution]
#  |
#  |  getSolution(...)
#  |      getSolution(self: highspy._core._Highs) -> HighsSolution
#  |
#  |  githash(...)
#  |      githash(self: highspy._core._Highs) -> str
#  |
#  |  modelStatusToString(...)
#  |      modelStatusToString(self: highspy._core._Highs, arg0: highspy._core.HighsModelStatus) -> str
#  |
#  |  passColName(...)
#  |      passColName(self: highspy._core._Highs, arg0: int, arg1: str) -> highspy._core.HighsStatus
#  |
#  |  passHessian(...)
#  |      passHessian(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. passHessian(self: highspy._core._Highs, arg0: highspy._core.HighsHessian) -> highspy._core.HighsStatus
#  |
#  |      2. passHessian(self: highspy._core._Highs, arg0: int, arg1: int, arg2: int, arg3: numpy.ndarray[numpy.int32], arg4: numpy.ndarray[numpy.int32], arg5: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  passModel(...)
#  |      passModel(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. passModel(self: highspy._core._Highs, arg0: highspy._core.HighsModel) -> highspy._core.HighsStatus
#  |
#  |      2. passModel(self: highspy._core._Highs, arg0: int, arg1: int, arg2: int, arg3: int, arg4: int, arg5: int, arg6: int, arg7: float, arg8: numpy.ndarray[numpy.float64], arg9: numpy.ndarray[numpy.float64], arg10: numpy.ndarray[numpy.float64], arg11: numpy.ndarray[numpy.float64], arg12: numpy.ndarray[numpy.float64], arg13: numpy.ndarray[numpy.int32], arg14: numpy.ndarray[numpy.int32], arg15: numpy.ndarray[numpy.float64], arg16: numpy.ndarray[numpy.int32], arg17: numpy.ndarray[numpy.int32], arg18: numpy.ndarray[numpy.float64], arg19: numpy.ndarray[numpy.int32]) -> highspy._core.HighsStatus
#  |
#  |      3. passModel(self: highspy._core._Highs, arg0: highspy._core.HighsLp) -> highspy._core.HighsStatus
#  |
#  |      4. passModel(self: highspy._core._Highs, arg0: int, arg1: int, arg2: int, arg3: int, arg4: int, arg5: float, arg6: numpy.ndarray[numpy.float64], arg7: numpy.ndarray[numpy.float64], arg8: numpy.ndarray[numpy.float64], arg9: numpy.ndarray[numpy.float64], arg10: numpy.ndarray[numpy.float64], arg11: numpy.ndarray[numpy.int32], arg12: numpy.ndarray[numpy.int32], arg13: numpy.ndarray[numpy.float64], arg14: numpy.ndarray[numpy.int32]) -> highspy._core.HighsStatus
#  |
#  |  passOptions(...)
#  |      passOptions(self: highspy._core._Highs, arg0: highspy._core.HighsOptions) -> highspy._core.HighsStatus
#  |
#  |  passRowName(...)
#  |      passRowName(self: highspy._core._Highs, arg0: int, arg1: str) -> highspy._core.HighsStatus
#  |
#  |  postsolve(...)
#  |      postsolve(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. postsolve(self: highspy._core._Highs, arg0: HighsSolution, arg1: HighsBasis) -> highspy._core.HighsStatus
#  |
#  |      2. postsolve(self: highspy._core._Highs, arg0: HighsSolution) -> highspy._core.HighsStatus
#  |
#  |  presolve(...)
#  |      presolve(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  readBasis(...)
#  |      readBasis(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  readModel(...)
#  |      readModel(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  readOptions(...)
#  |      readOptions(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  readSolution(...)
#  |      readSolution(self: highspy._core._Highs, arg0: str, arg1: int) -> highspy._core.HighsStatus
#  |
#  |  resetOptions(...)
#  |      resetOptions(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  run(...)
#  |      run(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  setBasis(...)
#  |      setBasis(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. setBasis(self: highspy._core._Highs, arg0: HighsBasis) -> highspy._core.HighsStatus
#  |
#  |      2. setBasis(self: highspy._core._Highs) -> highspy._core.HighsStatus
#  |
#  |  setCallback(...)
#  |      setCallback(self: highspy._core._Highs, arg0: Callable[[int, str, HighsCallbackDataOut, HighsCallbackDataIn, object], None], arg1: object) -> highspy._core.HighsStatus
#  |
#  |  setOptionValue(...)
#  |      setOptionValue(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. setOptionValue(self: highspy._core._Highs, arg0: str, arg1: bool) -> highspy._core.HighsStatus
#  |
#  |      2. setOptionValue(self: highspy._core._Highs, arg0: str, arg1: int) -> highspy._core.HighsStatus
#  |
#  |      3. setOptionValue(self: highspy._core._Highs, arg0: str, arg1: float) -> highspy._core.HighsStatus
#  |
#  |      4. setOptionValue(self: highspy._core._Highs, arg0: str, arg1: str) -> highspy._core.HighsStatus
#  |
#  |  setSolution(...)
#  |      setSolution(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. setSolution(self: highspy._core._Highs, arg0: HighsSolution) -> highspy._core.HighsStatus
#  |
#  |      2. setSolution(self: highspy._core._Highs, arg0: int, arg1: numpy.ndarray[numpy.int32], arg2: numpy.ndarray[numpy.float64]) -> highspy._core.HighsStatus
#  |
#  |  solutionStatusToString(...)
#  |      solutionStatusToString(self: highspy._core._Highs, arg0: int) -> str
#  |
#  |  startCallback(...)
#  |      startCallback(self: highspy._core._Highs, arg0: HighsCallbackType) -> highspy._core.HighsStatus
#  |
#  |  startCallbackInt(...)
#  |      startCallbackInt(self: highspy._core._Highs, arg0: int) -> highspy._core.HighsStatus
#  |
#  |  stopCallback(...)
#  |      stopCallback(self: highspy._core._Highs, arg0: HighsCallbackType) -> highspy._core.HighsStatus
#  |
#  |  stopCallbackInt(...)
#  |      stopCallbackInt(self: highspy._core._Highs, arg0: int) -> highspy._core.HighsStatus
#  |
#  |  version(...)
#  |      version(self: highspy._core._Highs) -> str
#  |
#  |  versionMajor(...)
#  |      versionMajor(self: highspy._core._Highs) -> int
#  |
#  |  versionMinor(...)
#  |      versionMinor(self: highspy._core._Highs) -> int
#  |
#  |  versionPatch(...)
#  |      versionPatch(self: highspy._core._Highs) -> int
#  |
#  |  writeBasis(...)
#  |      writeBasis(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  writeInfo(...)
#  |      writeInfo(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  writeModel(...)
#  |      writeModel(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  writeOptions(...)
#  |      writeOptions(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  writePresolvedModel(...)
#  |      writePresolvedModel(self: highspy._core._Highs, arg0: str) -> highspy._core.HighsStatus
#  |
#  |  writeSolution(...)
#  |      writeSolution(self: highspy._core._Highs, arg0: str, arg1: int) -> highspy._core.HighsStatus
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from highspy._core._Highs:
#  |
#  |  resetGlobalScheduler(...) method of builtins.PyCapsule instance
#  |      resetGlobalScheduler(arg0: bool) -> None
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
h = highspy.Highs()
h.readModel("test.lp");
h.silent()
B = BnB(h, [0], 1e-3)
# Out:
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms

# %%
B.start()
# Out:
# StackItem{
# 	Cuts:
# 	Solution:
# 		[8.5, 0.0]
# 	Dual value:
# 		-8.5
# }
# Cut[id: 0, lower: 0, upper: 8] | Cut[id: 0, lower: 9, upper: inf]
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms
# StackItem{
# 	Cuts:
# 		Cut[id: 0, lower: 0, upper: 8]
# 	Solution:
# 		[8.0, 0.3333333333333333]
# 	Dual value:
# 		-8.333333333333334
# }
# Cut[id: 1, lower: 0, upper: 0] | Cut[id: 1, lower: 1, upper: inf]
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms
# Running HiGHS 1.9.0 (git hash: fa40bdf): Copyright (c) 2024 HiGHS under MIT licence terms
# StackItem{
# 	Cuts:
# 		Cut[id: 0, lower: 0, upper: 8]
# 		Cut[id: 1, lower: 1, upper: inf]
# 	Solution:
# 		[7.0, 1.0]
# 	Dual value:
# 		-8.0
# }
# [7.0, 1.0]
# None | None
